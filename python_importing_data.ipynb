# %% [markdown]
# <a href="https://colab.research.google.com/github/Prithviraj2706/DS-training/blob/main/python_importing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing Packages

import pandas as pd  #used to import files #python data analysis package
import numpy as np   #used to do numerical analysis
import matplotlib.pyplot as plt

# %%
dict1={'India':'I love India','UK':10,'USA':False}
dict1
# Out:
# {'India': 'I love India', 'UK': 10, 'USA': False}

# %%
dict1['India']
# Out:
# 'I love India'

# %%
stats= pd.read_csv('/content/DemographicData.csv')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head(10)  #in brackert 10 stands for rows
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %%
stats.info() #gives complete details about the file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()   #will give stats of the numerical columns
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns=['CountryName','CountryCode','Birthrate','Internetusers','IncomeGroup']

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats[3:8]
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
stats.iloc[:,1:3].values    #iloc is for index location
# Out:
# array([['ABW', 10.244],
#        ['AFG', 35.253],
#        ['AGO', 45.985],
#        ['ALB', 12.877],
#        ['ARE', 11.044],
#        ['ARG', 17.716],
#        ['ARM', 13.308],
#        ['ATG', 16.447],
#        ['AUS', 13.2],
#        ['AUT', 9.4],
#        ['AZE', 18.3],
#        ['BDI', 44.151],
#        ['BEL', 11.2],
#        ['BEN', 36.44],
#        ['BFA', 40.551],
#        ['BGD', 20.142],
#        ['BGR', 9.2],
#        ['BHR', 15.04],
#        ['BHS', 15.339],
#        ['BIH', 9.062],
#        ['BLR', 12.5],
#        ['BLZ', 23.092],
#        ['BMU', 10.4],
#        ['BOL', 24.236],
#        ['BRA', 14.931],
#        ['BRB', 12.188],
#        ['BRN', 16.405],
#        ['BTN', 18.134],
#        ['BWA', 25.267],
#        ['CAF', 34.076],
#        ['CAN', 10.9],
#        ['CHE', 10.2],
#        ['CHL', 13.385],
#        ['CHN', 12.1],
#        ['CIV', 37.32],
#        ['CMR', 37.236],
#        ['COG', 37.011],
#        ['COL', 16.076],
#        ['COM', 34.326],
# ...

# %%
stats.iloc[:2,3:].values     #so if we use vales it will come as array
# Out:
# array([[78.9, 'High income'],
#        [5.9, 'Low income']], dtype=object)

# %%
stats.iloc[:2,3:]    #if we dont use values it come as data frames
# Out:
#    Internetusers  IncomeGroup
# 0           78.9  High income
# 1            5.9   Low income

# %%
stats.iloc[2:6:3,1:4:2]
# Out:
#   CountryCode  Internetusers
# 2         AGO           19.1
# 5         ARG           59.9

# %%
stats.iloc[[2,5],[1,3]]
# Out:
#   CountryCode  Internetusers
# 2         AGO           19.1
# 5         ARG           59.9

# %%
stats.Internetusers/stats.Birthrate
# Out:
# 0      7.702070
# 1      0.167362
# 2      0.415353
# 3      4.442028
# 4      7.968127
#          ...
# 190    0.607036
# 191    2.230216
# 192    0.051894
# 193    0.380519
# 194    0.517990
# Length: 195, dtype: float64

# %%
stats['New']=stats.Internetusers/stats.Birthrate #to create a new row

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup       New
# 0          High income  7.702070
# 1           Low income  0.167362
# 2  Upper middle income  0.415353
# 3  Upper middle income  4.442028
# 4          High income  7.968127

# %%
stats=stats.drop('New',1)
# Out:
# <ipython-input-29-4e86423f22b6>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   stats=stats.drop('New',1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#FILTERING
stats.Birthrate >40
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: Birthrate, Length: 195, dtype: bool

# %%
stats[stats.Birthrate>40]   #extracting data based on filter
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
stats[stats.Internetusers<10]
# Out:
#                   CountryName CountryCode  Birthrate  Internetusers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...

# %%
stats[(stats.Birthrate>40)&(stats.Internetusers<10)]
# Out:
#           CountryName CountryCode  Birthrate  Internetusers IncomeGroup
# 11            Burundi         BDI     44.151            1.3  Low income
# 14       Burkina Faso         BFA     40.551            9.1  Low income
# 115              Mali         MLI     44.138            3.5  Low income
# 127             Niger         NER     49.661            1.7  Low income
# 156           Somalia         SOM     43.891            1.5  Low income
# 167              Chad         TCD     45.745            2.3  Low income
# 192  Congo, Dem. Rep.         COD     42.394            2.2  Low income

# %%
stats[(stats.IncomeGroup=='Low income')&(stats.Internetusers>3)&(stats.Birthrate<50)]
# Out:
#                   CountryName CountryCode  Birthrate  Internetusers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# 99                    Liberia         LBR     35.521           3.20
# 115                      Mali         MLI     44.138           3.50
# 120                Mozambique         MOZ     39.705           5.40
# 123                    Malawi         MWI     39.459           5.05
# ...

# %%
stats[(stats.IncomeGroup=='Low income')&(stats.Internetusers>3)&(stats.Birthrate>50)]
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, Birthrate, Internetusers, IncomeGroup]
# Index: []

# %%
stats[(stats.IncomeGroup=='Low income')&(stats.Internetusers>3)&(stats.Birthrate>40)]
# Out:
#       CountryName CountryCode  Birthrate  Internetusers IncomeGroup
# 14   Burkina Faso         BFA     40.551            9.1  Low income
# 65    Gambia, The         GMB     42.525           14.0  Low income
# 115          Mali         MLI     44.138            3.5  Low income
# 178        Uganda         UGA     43.474           16.2  Low income

# %%
stats[(stats.IncomeGroup!='Low income')&(stats.Internetusers>10)&(stats.Birthrate>40)]
# Out:
#     CountryName CountryCode  Birthrate  Internetusers          IncomeGroup
# 2        Angola         AGO     45.985           19.1  Upper middle income
# 128     Nigeria         NGA     40.045           38.0  Lower middle income
# 193      Zambia         ZMB     40.471           15.4  Lower middle income

# %%
len(stats[(stats.IncomeGroup=='Low income')&(stats.Internetusers>3)&(stats.Birthrate>40)])
# Out:
# 4

# %%
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats.iat[2,2]    #IAT STANDS FOR INDEX AT USED TO GET A SPECIFIC VALUE
# Out:
# 45.985

# %%
stats.iloc[2,2]
# Out:
# 45.985

# %%
stats.at[2,'Birthrate']
# Out:
# 45.985

# %%
import seaborn as sns       #used to get graphical data

# %%
sns.boxplot(data=stats,x='IncomeGroup',y='Birthrate')
# Out:
# <AxesSubplot:xlabel='IncomeGroup', ylabel='Birthrate'>

# %%
sns.boxplot(data=stats,x='IncomeGroup',y='Internetusers')
# Out:
# <AxesSubplot:xlabel='IncomeGroup', ylabel='Internetusers'>

# %%
sns.lmplot(data=stats,x='Internetusers',y='Birthrate')  #linear model plot

# %%
sns.lmplot(data=stats,x='Internetusers',y='Birthrate',hue="IncomeGroup")    #hue is to add colour

# %%
sns.lmplot(data=stats,x='Internetusers',y='Birthrate',hue="IncomeGroup", fit_reg= False)  #fit regression line

# %%
sns.lmplot(data=stats,x='Internetusers',y='Birthrate',hue="IncomeGroup", fit_reg= False,scatter_kws={'s':200})    #key word argument used to increse the dot size
